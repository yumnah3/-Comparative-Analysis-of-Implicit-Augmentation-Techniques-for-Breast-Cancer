# %%
import pandas as pd
from sklearn.metrics import roc_auc_score,matthews_corrcoef
from sklearn.model_selection import train_test_split
import time
import logging
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score,StratifiedKFold
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, roc_curve,auc
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

# %%
# Set a random seed for reproducibility
random_seed = 42
np.random.seed(random_seed)

# Suppress LightGBM output
logging.getLogger('lightgbm').setLevel(logging.ERROR)

# Load training data
df_train = pd.read_csv('mlo+deep+mixup+stem.csv')
df_test = pd.read_csv('mlo_only_test_dataset_10.csv')

X_train = df_train.drop('diagnosis', axis=1)
y_train = df_train['diagnosis']

scaler = preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)



# Load test data

df_test = df_test.drop(df_test.loc[:, ['volume', 'case', 'image_name', 'side','view','segment']], axis=1)
X_test = df_test.drop('diagnosis', axis=1)
y_test = df_test['diagnosis']

X_test = scaler.transform(X_test)

#adding validation step
#X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=42)

# %%
df_test.size
# Out:
# 416150

# %%
# Initialize lists to store metrics
fpr_list, tpr_list, mcc_list, auc_list = [], [], [], []

for run in range(30):
    # Build a simple neural network model
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
    model.add(Dropout(0.5))
    model.add(Dense(32, activation='relu', kernel_regularizer='l2'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    # Compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Use early stopping to prevent overfitting
    early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

    #Train model without validation
    model.fit(X_train, y_train, epochs=5, batch_size=64,callbacks=[early_stopping])


    # Train the model with validation
    #history = model.fit(X_train, y_train, epochs=30, batch_size=64,validation_data=(X_test, y_test),callbacks=[early_stopping])

    #Plot learning curves for training and validation loss
    #plt.plot(history.history['loss'], label='Training Loss')
    #plt.plot(history.history['val_loss'], label='Validation Loss')
    #plt.legend()
    #plt.show()

    # Make predictions on the test set
    y_pred_proba = model.predict(X_test)

    y_pred = np.round(y_pred_proba)

    y_pred_binary = (y_pred_proba > 0.5).astype(int)

    # Calculate Matthews correlation coefficient (MCC)
    mcc_value = matthews_corrcoef(y_test, y_pred_binary)

    # Calculate evaluation metrics
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc1 = roc_auc_score(y_test, y_pred_proba)

    # Compute ROC curve
    fpr, tpr, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(fpr, tpr)

    # Find the index of the threshold closest to 0.5
    threshold_value = 0.5
    index_closest_threshold = np.argmin(np.abs(thresholds - threshold_value))

    # Print FPR and TPR at the specified threshold
    fpr_at_threshold = fpr[index_closest_threshold]
    tpr_at_threshold = tpr[index_closest_threshold]

    print(f"At threshold {threshold_value:.2f}: FPR = {fpr_at_threshold:.4f}, TPR = {tpr_at_threshold:.4f}")

    # Print or store the metrics as needed
    metrics_dict = {
        'AUC': auc1,
        'MCC': mcc_value,
        'FPR': fpr_at_threshold,
        'TPR': tpr_at_threshold
    }

    # Append metrics to lists
    fpr_list.append(fpr_at_threshold)
    tpr_list.append(tpr_at_threshold)
    mcc_list.append(mcc_value)
    auc_list.append(auc1)

# Create a DataFrame to store the metrics
results_df = pd.DataFrame({
    'Run': np.arange(1, 31),
    'FPR': fpr_list,
    'TPR': tpr_list,
    'MCC': mcc_list,
    'AUC': auc_list
})


#Save the DataFrame to a CSV file
results_df.to_csv('mlo+deep+mixup+stem_MLP.csv', index=False)
# Out:
# Epoch 1/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.8239 - accuracy: 0.7984
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5222 - accuracy: 0.9068
# Epoch 3/5
# 90/90 [==============================] - 3s 30ms/step - loss: 0.3868 - accuracy: 0.9341
# Epoch 4/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.3099 - accuracy: 0.9470
# Epoch 5/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.2583 - accuracy: 0.9510
# 13/13 [==============================] - 0s 6ms/step
# At threshold 0.50: FPR = 0.0911, TPR = 0.6364
# Epoch 1/5
# 90/90 [==============================] - 3s 30ms/step - loss: 0.8526 - accuracy: 0.7965
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5535 - accuracy: 0.9047
# Epoch 3/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.4272 - accuracy: 0.9292
# Epoch 4/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.3357 - accuracy: 0.9459
# Epoch 5/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5693 - accuracy: 0.8981
# Epoch 3/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.4348 - accuracy: 0.9287
# Epoch 4/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.3441 - accuracy: 0.9464
# Epoch 5/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.2769 - accuracy: 0.9563
# 13/13 [==============================] - 0s 7ms/step
# At threshold 0.50: FPR = 0.0859, TPR = 0.6818
# Epoch 1/5
# 90/90 [==============================] - 3s 30ms/step - loss: 0.8283 - accuracy: 0.8043
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5530 - accuracy: 0.9021
# Epoch 3/5
# 90/90 [==============================] - 3s 30ms/step - loss: 0.4150 - accuracy: 0.9355
# Epoch 4/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.3243 - accuracy: 0.9442
# Epoch 5/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.2624 - accuracy: 0.9563
# 13/13 [==============================] - 0s 8ms/step
# At threshold 0.50: FPR = 0.0964, TPR = 0.6818
# Epoch 1/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.8066 - accuracy: 0.8014
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5022 - accuracy: 0.9083
# Epoch 3/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.3745 - accuracy: 0.9334
# Epoch 4/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.2827 - accuracy: 0.9510
# Epoch 5/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.2387 - accuracy: 0.9551
# 13/13 [==============================] - 0s 6ms/step
# At threshold 0.50: FPR = 0.0781, TPR = 0.6364
# Epoch 1/5
# 90/90 [==============================] - 3s 30ms/step - loss: 0.8431 - accuracy: 0.7877
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5327 - accuracy: 0.9038
# Epoch 3/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.4143 - accuracy: 0.9263
# Epoch 4/5
# 90/90 [==============================] - 3s 30ms/step - loss: 0.3228 - accuracy: 0.9438
# Epoch 5/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.2559 - accuracy: 0.9550
# 13/13 [==============================] - 0s 6ms/step
# At threshold 0.50: FPR = 0.0807, TPR = 0.6818
# Epoch 1/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.8229 - accuracy: 0.8010
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5121 - accuracy: 0.9037
# Epoch 3/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.3812 - accuracy: 0.9318
# Epoch 4/5
# 90/90 [==============================] - 3s 30ms/step - loss: 0.2952 - accuracy: 0.9473
# Epoch 5/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.2405 - accuracy: 0.9532
# 13/13 [==============================] - 0s 7ms/step
# At threshold 0.50: FPR = 0.0781, TPR = 0.5909
# Epoch 1/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.9179 - accuracy: 0.7929
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5653 - accuracy: 0.9017
# Epoch 3/5
# 90/90 [==============================] - 3s 30ms/step - loss: 0.4368 - accuracy: 0.9315
# Epoch 4/5
# 90/90 [==============================] - 3s 30ms/step - loss: 0.3500 - accuracy: 0.9426
# Epoch 5/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.3056 - accuracy: 0.9457
# 13/13 [==============================] - 0s 7ms/step
# At threshold 0.50: FPR = 0.0807, TPR = 0.5909
# Epoch 1/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.8378 - accuracy: 0.7946
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5359 - accuracy: 0.9012
# Epoch 3/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.4101 - accuracy: 0.9311
# Epoch 4/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.3150 - accuracy: 0.9475
# Epoch 5/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.2562 - accuracy: 0.9546
# 13/13 [==============================] - 0s 6ms/step
# At threshold 0.50: FPR = 0.0911, TPR = 0.6818
# Epoch 1/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.8720 - accuracy: 0.7830
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5535 - accuracy: 0.8937
# Epoch 3/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.4118 - accuracy: 0.9278
# Epoch 4/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.3317 - accuracy: 0.9414
# Epoch 5/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.2802 - accuracy: 0.9485
# 13/13 [==============================] - 0s 7ms/step
# At threshold 0.50: FPR = 0.0755, TPR = 0.7727
# Epoch 1/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.8741 - accuracy: 0.7795
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5520 - accuracy: 0.9003
# Epoch 3/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.4216 - accuracy: 0.9290
# Epoch 4/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.3308 - accuracy: 0.9456
# Epoch 5/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.2649 - accuracy: 0.9565
# 13/13 [==============================] - 0s 6ms/step
# At threshold 0.50: FPR = 0.0755, TPR = 0.6818
# Epoch 1/5
# 90/90 [==============================] - 3s 30ms/step - loss: 0.8906 - accuracy: 0.7734
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5700 - accuracy: 0.8899
# Epoch 3/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.4306 - accuracy: 0.9193
# Epoch 4/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.3265 - accuracy: 0.9400
# Epoch 5/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.2624 - accuracy: 0.9513
# 13/13 [==============================] - 0s 6ms/step
# At threshold 0.50: FPR = 0.0911, TPR = 0.7727
# Epoch 1/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.8382 - accuracy: 0.7970
# Epoch 2/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.5101 - accuracy: 0.9104
# Epoch 3/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.3843 - accuracy: 0.9365
# Epoch 4/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.3015 - accuracy: 0.9482
# Epoch 5/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.2417 - accuracy: 0.9562
# 13/13 [==============================] - 0s 7ms/step
# At threshold 0.50: FPR = 0.0964, TPR = 0.6818
# Epoch 1/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.8284 - accuracy: 0.7997
# Epoch 2/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.5462 - accuracy: 0.9071
# Epoch 3/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.4180 - accuracy: 0.9285
# Epoch 4/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.3414 - accuracy: 0.9430
# Epoch 5/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.2704 - accuracy: 0.9563
# 13/13 [==============================] - 0s 7ms/step
# At threshold 0.50: FPR = 0.0781, TPR = 0.6364
# Epoch 1/5
# 90/90 [==============================] - 4s 32ms/step - loss: 0.8295 - accuracy: 0.8057
# Epoch 2/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.5287 - accuracy: 0.9040
# Epoch 3/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.4124 - accuracy: 0.9270
# Epoch 4/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.3182 - accuracy: 0.9492
# Epoch 5/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.2570 - accuracy: 0.9560
# 13/13 [==============================] - 0s 6ms/step
# At threshold 0.50: FPR = 0.0911, TPR = 0.7273
# Epoch 1/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.8185 - accuracy: 0.8216
# Epoch 2/5
# 90/90 [==============================] - 3s 32ms/step - loss: 0.5350 - accuracy: 0.9043
# Epoch 3/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.4007 - accuracy: 0.9325
# Epoch 4/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.3229 - accuracy: 0.9426
# Epoch 5/5
# 90/90 [==============================] - 3s 31ms/step - loss: 0.2559 - accuracy: 0.9525
# 13/13 [==============================] - 0s 7ms/step
# At threshold 0.50: FPR = 0.0807, TPR = 0.6364
